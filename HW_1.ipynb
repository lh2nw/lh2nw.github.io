# %%
# 1. Ask the user for their name
name = input("What is your name? ")

# 2. Print: Hello, [name]!
print(f"Hello, {name}!")
# Out:
# What is your name? Lexi
# Hello, Lexi!

# %%
#1. Ask for 2 numbers
num1 = int(input("Pick a number: "))
num2 = int(input("Pick another number: "))

#2. Print the sum
print(f"The sum of {num1} and {num2} is {num1 + num2}")

#3. Print the difference
print(f"The difference of {num1} and {num2} is {num1 - num2}")

#4. Print the product
print(f"The product of {num1} and {num2} is {num1 * num2}")

#5. Print the quotient
print(f"The quotient of {num1} and {num2} is {num1 / num2}")
# Out:
# Pick a number: 4
# Pick another number: 6
# The sum of 4 and 6 is 10
# The difference of 4 and 6 is -2
# The product of 4 and 6 is 24
# The quotient of 4 and 6 is 0.6666666666666666

# %%
#1. Ask for a temperature in celcius
# We use float() because temperatures often have decimals
celsius = float(input("Enter temperature in Celsius: "))

# 2. Convert it to Fahrenheit
fahrenheit = (celsius * 9/5) + 32

# 3. Print the result
print(f"{celsius}°C is equal to {fahrenheit}°F")
# Out:
# Enter temperature in Celsius: 35
# 35.0°C is equal to 95.0°F
