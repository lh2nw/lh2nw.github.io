# %% [markdown]
# <a href="https://colab.research.google.com/github/lh2nw/lh2nw.github.io/blob/main/Quiz3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
N = 0

for k in range(1, 100001):
    if k % 2 == 0 and k % 3 == 0 and k % 7 == 0:
        N = N + 1

print(N)
# Out:
# 2380
